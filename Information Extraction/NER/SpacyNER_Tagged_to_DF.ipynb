# %%
import time
from pprint import pprint
from itertools import *

import pandas as pd
pd.set_option('display.max_columns', None)
# import swifter

import spacy
nlp = spacy.load('en_core_web_lg')

# %%
# EntityTypes = ["PERSON", "NORP", "ORG", "FAC", "GPE", "LOC", "PRODUCT", "EVENT", "WORK_OF_ART"]

# %%
df = pd.read_csv(r"D:\Work\Coding\Data\some-news.csv")
df = df.drop("Unnamed: 0", axis=1)
df = df.drop("Unnamed: 0.1", axis=1)
df['article'] = df['article'].astype(str)

# %%
def getEnts(i):
    doc = nlp(i)
    entities = {key: list(set(map(lambda x: str(x), g))) for key, g in groupby(sorted(doc.ents, key=lambda x: x.label_), lambda x: x.label_)}
    
    return entities

def addEnts(dataframe, columnName):

    extracted = []

    for i, row in dataframe.iterrows():
        ents = getEnts(row[columnName])
        extracted.append(ents)

    dataframe["ExtractedEnts"] = extracted
    
    return dataframe

def splitEnts(dataframe):
    df_temp = pd.json_normalize(dataframe['ExtractedEnts'])
    dataframe = pd.concat([dataframe, df_temp], axis=1)
    
    return dataframe

# %%
starttime = time.time()
# df2['new_text'] = df2.swifter.apply(lambda row: getEnts(row['article']), axis=1) 

df = addEnts(df, 'article')

print(f"{time.time() - starttime} seconds")
# Out:
# 73.30217814445496 seconds

# %%
starttime = time.time()

df = splitEnts(df)

print(f"{time.time() - starttime} seconds")
# Out:
# 0.040216684341430664 seconds

# %%
df
# Out:
#                date  year  month  day            author  \
# 0    09-12-16 18:31  2016     12    9       Lee Drutman
# 1    07-10-16 21:26  2016     10    7       Scott Davis
# 2    26-01-18 00:00  2018      1   26               NaN
# 3    27-06-19 00:00  2019      6   27               NaN
# 4    27-01-16 00:00  2016      1   27               NaN
# ..              ...   ...    ...  ...               ...
# 990  20-07-18 00:00  2018      7   20               NaN
# 991  07-03-16 16:00  2016      3    7         Tim Shiel
# 992  20-12-16 00:00  2016     12   20               NaN
# 993  08-12-17 00:00  2017     12    8               NaN
# 994  03-11-17 12:01  2017     11    3  Tanza Loudenback
#
#                                                  title  \
# 0    We should take concerns about the health of li...
# 1    Colts GM Ryan Grigson says Andrew Luck's contr...
# 2         Trump denies report he ordered Mueller fired
# 3    France's Sarkozy reveals his 'Passions' but in...
# 4    Paris Hilton: Woman In Black For Uncle Monty's...
# ..                                                 ...
# 990  Christian Bale Shows Off Extreme Weight Loss A...
# 991  THUMP Australia's Monthly Oceanic Report Will ...
# 992  Nicole Kidman & Keith Urban Enjoy Christmas in...
# 993  Palestinian president says U.S. can no longer ...
# 994  Inside a Los Angeles apartment that rents for ...
#
#                                                article  \
# 0    This post is part of Polyarchy, an independent...
# 1     The Indianapolis Colts made Andrew Luck the h...
# 2    DAVOS, Switzerland (Reuters) - U.S. President ...
# 3    PARIS (Reuters) - Former French president Nico...
# 4    Paris Hilton arrived at LAX Wednesday dressed ...
# ..                                                 ...
# 990  Christian Bale's ditched any vestige of Dick C...
# 991  The Oceanic Report is our new column bringing ...
# 992  Nicole Kidman and Keith Urban might have a whi...
# 993  GAZA (Reuters) - The United States cannot brok...
# 994  The most expensive apartment for rent in Los A...
#
#                                                    url     section  \
# 0    https://www.vox.com/polyarchy/2016/12/9/138983...         NaN
# 1    https://www.businessinsider.com/colts-gm-ryan-...         NaN
# 2    https://www.reuters.com/article/us-davos-meeti...       Davos
# 3    https://www.reuters.com/article/france-politic...  World News
# 4    https://www.tmz.com/2016/01/27/paris-hilton-mo...         NaN
# ..                                                 ...         ...
# 990  https://www.tmz.com/2018/07/20/christian-bale-...         NaN
# 991  https://www.vice.com/en_us/article/wnyx4w/thum...      Noisey
# 992  https://www.tmz.com/2016/12/20/nicole-kidman-k...         NaN
# 993  https://www.reuters.com/article/us-usa-trump-i...  World News
# 994                                                NaN         NaN
#
#           publication                                      ExtractedEnts  \
# 0                 Vox  {'CARDINAL': ['one'], 'DATE': ['30s', 'the pas...
# 1    Business Insider  {'CARDINAL': ['32'], 'DATE': ['five-year', 'a ...
# 2             Reuters  {'CARDINAL': ['four'], 'DATE': ['Friday', 'Thu...
# 3             Reuters  {'CARDINAL': ['one'], 'DATE': ['This month', '...
# 4                 TMZ  {'DATE': ['Wednesday', 'Sunday'], 'GPE': ['Par...
# ..                ...                                                ...
# 990               TMZ  {'CARDINAL': ['one'], 'DATE': ['7 months ago',...
# 991              Vice  {'CARDINAL': ['ten'], 'DATE': ['This month', '...
# 992               TMZ  {'DATE': ['the holidays', 'Monday', 'Christmas...
# 993           Reuters  {'DATE': ['Friday'], 'GPE': ['Jerusalem', 'Isr...
# 994               NaN  {'CARDINAL': ['1,000', 'three', 'two'], 'GPE':...
#
#                 CARDINAL                                               DATE  \
# 0                  [one]  [30s, the past two weeks, 30-something, the ne...
# 1                   [32]  [five-year, a year ago, Friday, this year, las...
# 2                 [four]                      [Friday, Thursday, last June]
# 3                  [one]  [This month, 2017, May, 2007-2012, 2014, Thurs...
# 4                    NaN                                [Wednesday, Sunday]
# ..                   ...                                                ...
# 990                [one]                             [7 months ago, months]
# 991                [ten]                                 [This month, 2016]
# 992                  NaN          [the holidays, Monday, Christmas, summer]
# 993                  NaN                                           [Friday]
# 994  [1,000, three, two]                                                NaN
#
#                                                    GPE  \
# 0                                         [Washington]
# 1                                                  NaN
# 2                                  [U.S., Switzerland]
# 3                                      [PARIS, France]
# 4                   [Paris, Brinson, LAX, Switzerland]
# ..                                                 ...
# 990                                            [Italy]
# 991            [New Zealand, Perth, Sydney, Melbourne]
# 992                                           [Sydney]
# 993  [Jerusalem, Israel, the United States, The Uni...
# 994                                      [Los Angeles]
#
#                                                    LOC  \
# 0                                        [New America]
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 990                                                NaN
# 991  [the Cook Islands, Rarotonga island, Swan Rive...
# 992                                                NaN
# 993                                                NaN
# 994                                                NaN
#
#                                                    ORG  \
# 0    [the New York Times, New York Times, Journal o...
# 1    [Colts, NFL, Denver Broncos, The Indianapolis ...
# 2    [DAVOS, Reuters, Davos, The New York Times, Wh...
# 3                          [Reuters, Macron, Le Point]
# 4                                                  NaN
# ..                                                 ...
# 990                             [CB, Christian Bale's]
# 991  [NASA, Tourist Kid, SoundCloud, Twitter, Uni, ...
# 992                                      [Keith Urban]
# 993                                          [Reuters]
# 994                                          [Chevron]
#
#                                                 PERSON      WORK_OF_ART  \
# 0    [Erik Voeten, Yascha Mounk, Polyarchy, Amanda ...  [Mounk and Foa]
# 1    [Colts, Peyton Manning, Ryan Grigson, Luck, An...              NaN
# 2    [Steve Holland, Trump, Donald Trump, Robert Mu...              NaN
# 3    [Luke Baker, Carla Bruni, Simon Carraud, Franc...              NaN
# 4    [Monty Brinson, Kim Richards, Monty, Paris Hil...              NaN
# ..                                                 ...              ...
# 990                                      [Dick Cheney]              NaN
# 991  [Matthew Kirkis, Tim Shiel, Mei Saraswati, Kan...     [Cold Crush]
# 992          [Nicole, shirtless, Keith, Nicole Kidman]              NaN
# 993  [Alison Williams, Nidal al-Mughrabi, Donald Tr...              NaN
# 994                                                NaN              NaN
#
#                                                  MONEY  ORDINAL    PRODUCT  \
# 0                                                  NaN      NaN        NaN
# 1    [$18.4 million, less than $1 million, $15 mill...   [30th]  [Broncos]
# 2                                                  NaN      NaN        NaN
# 3                                                  NaN  [first]        NaN
# 4                                                  NaN      NaN        NaN
# ..                                                 ...      ...        ...
# 990                                                NaN      NaN        NaN
# 991                                                NaN      NaN       [EP]
# 992                                                NaN      NaN        NaN
# 993                                                NaN      NaN        NaN
# 994                                        [100,000-a]      NaN        NaN
#
#                                  NORP PERCENT  \
# 0                                 NaN     NaN
# 1                                 NaN     NaN
# 2                                 NaN     NaN
# 3                  [European, French]     NaN
# 4                                 NaN     NaN
# ..                                ...     ...
# 990                       [Christian]     NaN
# 991            [Australian, Romanian]     NaN
# 992                               NaN     NaN
# 993  [Israeli, Palestinian, American]     NaN
# 994                               NaN     NaN
#
#                                               QUANTITY              TIME  FAC  \
# 0                                                  NaN               NaN  NaN
# 1                                                  NaN               NaN  NaN
# 2                                                  NaN               NaN  NaN
# 3                                                  NaN               NaN  NaN
# 4                                                  NaN               NaN  NaN
# ..                                                 ...               ...  ...
# 990  [about 228 pounds, roughly 100 lbs, almost 70 ...  [Friday morning]  NaN
# 991                                                NaN               NaN  NaN
# 992                                                NaN               NaN  NaN
# 993                                                NaN               NaN  NaN
# 994                                                NaN               NaN  NaN
#
#     EVENT LANGUAGE  LAW
# 0     NaN      NaN  NaN
# 1     NaN      NaN  NaN
# 2     NaN      NaN  NaN
# 3     NaN      NaN  NaN
# 4     NaN      NaN  NaN
# ..    ...      ...  ...
# 990   NaN      NaN  NaN
# 991  [EP]      NaN  NaN
# 992   NaN      NaN  NaN
# 993   NaN      NaN  NaN
# 994   NaN      NaN  NaN
#
# [995 rows x 29 columns]

# %%
df.to_csv("Some News (NER Tagged).csv")
